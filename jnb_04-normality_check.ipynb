# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = pd.read_csv('Daily_website_visitors.csv')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2167 entries, 0 to 2166
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row                2167 non-null   int64
#  1   Day                2167 non-null   str
#  2   Day.Of.Week        2167 non-null   int64
#  3   Date               2167 non-null   str
#  4   Page.Loads         2167 non-null   str
#  5   Unique.Visits      2167 non-null   str
#  6   First.Time.Visits  2167 non-null   str
#  7   Returning.Visits   2167 non-null   str
# dtypes: int64(2), str(6)
# memory usage: 135.6 KB
